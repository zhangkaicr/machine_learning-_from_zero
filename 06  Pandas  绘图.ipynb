# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("input/data_.xlsx",index_col=0)

# %%
data_ = data.copy()
data_
# Out:
#          Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# ID
# 1275807                4                        2                         4
# 1193683                1                        1                         2
# 1170419               10                       10                        10
# 1190386                4                        6                         6
# 1202125                4                        1                         1
# ...                  ...                      ...                       ...
# 493452                 1                        1                         3
# 1116132                6                        3                         4
# 1133136                3                        1                         1
# 1158247                1                        1                         1
# 1206314                1                        2                         3
#
#          Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ID
# 1275807                  3                            2            2
# 1193683                  1                            3            1
# 1170419                  8                            2           10
# 1190386                  5                            7            6
# 1202125                  1                            2            1
# ...                    ...                          ...          ...
# 493452                   1                            2            1
# 1116132                  1                            5            2
# 1133136                  1                            2            3
# 1158247                  1                            2            1
# 1206314                  1                            2            1
#
#          Bland Chromatin  Normal Nucleoli  Mitoses  Class  Thickness_classnum  \
# ID
# 1275807                2                1        1      2                   2
# 1193683                1                1        1      2                   1
# 1170419                4                1        1      4                   3
# 1190386                7                7        3      4                   2
# 1202125                3                1        1      2                   2
# ...                  ...              ...      ...    ...                 ...
# 493452                 1                1        1      2                   1
# 1116132                3                9        1      4                   2
# 1133136                3                1        1      2                   1
# 1158247                2                1        1      2                   1
# 1206314                1                1        1      2                   1
#
#          Cell Size _small  Cell Size _medium  Cell Size _big Thickness_class  \
# ID
# 1275807                 1                  0               0          medium
# 1193683                 1                  0               0            thin
# 1170419                 0                  0               1           thick
# 1190386                 0                  1               0          medium
# 1202125                 1                  0               0          medium
# ...                   ...                ...             ...             ...
# 493452                  1                  0               0            thin
# 1116132                 1                  0               0          medium
# 1133136                 1                  0               0            thin
# 1158247                 1                  0               0            thin
# 1206314                 1                  0               0            thin
#
#         Cell Size
# ID
# 1275807     small
# 1193683     small
# 1170419       big
# 1190386    medium
# 1202125     small
# ...           ...
# 493452      small
# 1116132     small
# 1133136     small
# 1158247     small
# 1206314     small
#
# [645 rows x 16 columns]

# %%
data_ = data_.iloc[:,:10]

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data_, alpha=1, figsize=(18,18))
plt.show()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(data_,class_column='Class',color=['k','r'])
plt.show()

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(data_,class_column='Class', color=['k','r'])
plt.show()

# %%
from pandas.plotting import radviz

# %%
radviz(data_,class_column='Class', color=['k','r'])
plt.show()
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:152: RuntimeWarning: invalid value encountered in true_divide
#   y = (s * row_).sum(axis=0) / row.sum()
